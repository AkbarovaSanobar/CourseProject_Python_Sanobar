# %% [markdown]
# Relation between zodiac of born year and Nobel winners categories

# %% [markdown]
# pie chart of born year zodiac frequency in categories of economy and physics

# %%
plt.style.use("fivethirtyeight")
#fig, axs = plt.subplots(1, 2)
slices1 = [0.083333333,
0.095238095,
0.083333333,
0.107142857,
0.083333333,
0.071428571,
0.083333333,
0.119047619,
0.083333333,
0.095238095,
0.05952381,
0.035714287
]

slices5 = [0.096774194,
0.073732719,
0.073732719,
0.105990783,
0.073732719,
0.073732719,
0.059907834,
0.092165899,
0.092165899,
0.078341014,
0.092165899,
0.087557604
]

labels = ['dog', 'dragon', 'goat', 'horse', 'monkey', 'ox',  'pig', 'rabbit', 'rat', 'rooster', 'snake', 'tiger']
colors = ['red', 'lightgreen', 'yellow', 'blue', 'lightpink', 'cyan', 'lightcoral', 'white', 'darkgreen', 'grey', 'tan', 'teal']

#axs[0, 0].pie(slices1, labels=labels, colors=colors, wedgeprops={'edgecolor': 'black'}, autopct='%1.1f%%', shadow=True)
patches, texts, autotexts = plt.pie(slices1, labels=labels, colors=colors, wedgeprops={'edgecolor': 'black'}, autopct='%1.1f%%', shadow=True, normalize=True, textprops={'size': 'smaller'})
plt.title("economy")
plt.tight_layout()
autotexts[0].set_color('white')
plt.show()


patches, texts, autotexts = plt.pie(slices5, labels=labels, colors=colors, wedgeprops={'edgecolor': 'black'}, autopct='%1.1f%%', shadow=True, normalize=False, textprops={'size': 'smaller'})
plt.title("physics")
plt.tight_layout()
autotexts[0].set_color('white')
plt.show()

# %% [markdown]
# pie chart of born year zodiac frequency in categories of medicine and chemistry

# %%
plt.style.use("fivethirtyeight")
labels = ['dog', 'dragon', 'goat', 'horse', 'monkey', 'ox',  'pig', 'rabbit', 'rat', 'rooster', 'snake', 'tiger']
colors = ['red', 'lightgreen', 'yellow', 'blue', 'lightpink', 'cyan', 'lightcoral', 'white', 'darkgreen', 'grey', 'tan', 'teal']
slices6 = [0.0534,
0.069,
0.096,
0.085,
0.101,
0.08,
0.069,
0.09,
0.096,
0.074,
0.106,
0.074
]

slices3 = [0.080357143,
0.075892857,
0.0625,
0.075892857,
0.075892857,
0.071428571,
0.084821429,
0.107142857,
0.107142857,
0.075892857,
0.111607143,
0.071428571
]



#axs[1, 0].pie(slices3, labels=labels, colors=colors, wedgeprops={'edgecolor': 'black'})
plt.pie(slices3, labels=labels, colors=colors, wedgeprops={'edgecolor': 'black'}, autopct='%1.1f%%', shadow=True, normalize=False, textprops={'size': 'smaller'})
plt.title("medicine")
plt.tight_layout()
autotexts[0].set_color('white')
plt.show()



plt.pie(slices6, labels=labels, colors=colors, wedgeprops={'edgecolor': 'black'}, autopct='%1.1f%%', shadow=True, normalize=False, textprops={'size': 'smaller'})
plt.title("chemistry")
plt.tight_layout()
autotexts[0].set_color('white')
plt.show()

# %% [markdown]
# pie chart of born year zodiac frequency in categories of literature and peace

# %%
plt.style.use("fivethirtyeight")
labels = ['dog', 'dragon', 'goat', 'horse', 'monkey', 'ox',  'pig', 'rabbit', 'rat', 'rooster', 'snake', 'tiger']
colors = ['red', 'lightgreen', 'yellow', 'blue', 'lightpink', 'cyan', 'lightcoral', 'white', 'darkgreen', 'grey', 'tan', 'teal']

slices2 = [0.060344828,
0.129310345,
0.094827586,
0.094827586,
0.025862069,
0.077586207,
0.112068966,
0.077586207,
0.086206897,
0.051724138,
0.103448276,
0.086206897
]
slices4 = [0.056603774,
0.103773585,
0.08490566,
0.066037736,
0.056603774,
0.150943396,
0.113207547,
0.056603774,
0.094339623,
0.056603774,
0.075471698,
0.08490566
]
plt.pie(slices4, labels=labels, colors=colors, wedgeprops={'edgecolor': 'black'}, autopct='%1.1f%%', shadow=True, normalize=False, textprops={'size': 'smaller'})
plt.title("peace")
plt.tight_layout()
autotexts[0].set_color('white')
plt.show()

#axs[0, 1].pie(slices2, labels=labels, colors=colors, wedgeprops={'edgecolor': 'black'})
plt.pie(slices2, labels=labels, colors=colors, wedgeprops={'edgecolor': 'black'}, autopct='%1.1f%%', shadow=True, normalize=False, textprops={'size': 'smaller'})
plt.title("literature")
plt.tight_layout()
autotexts[0].set_color('white')
plt.show()

# %% [markdown]
# zodiac of winners in economy, literature and peace

# %%
from typing import Sized
import pandas as pd

import numpy as nm
from matplotlib import pyplot as plt

hamma= pd.read_csv('C:\\Users\\HP PAVILION GAMING\\OneDrive\\Рабочий стол\\new19_9\\birlashgan.csv')


plt.plot(hamma.year_zodiac, hamma.eco_frequency, color='blue')
plt.plot(hamma.year_zodiac, hamma.lit_frequency, color='red')
plt.plot(hamma.year_zodiac, hamma.pe_frequency, color = 'green')

font1 = {'family':'serif','color':'blue','size':20}
plt.title('Nobel prize winners\' zodiacs of born year and categories of economy, literature, peace', fontdict = font1, loc = 'center')
plt.legend(['economy', 'literature',  'peace'], bbox_to_anchor=(0.9,1), loc="upper left")
#plt.legend(bbox_to_anchor=(1.05,1))
plt.xlabel('zodiacs of year')
plt.xticks(rotation=90)
plt.ylabel('frequency')

ax = plt.subplot()
ax.grid(True)
plt.show()
# Out:
# <ipython-input-80-646bd42a8dd0>:22: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot()

# %% [markdown]
# zodiac of winners in medicine, chemistry and physics

# %%
from typing import Sized
import pandas as pd
import numpy as nm
from matplotlib import pyplot as plt

hamma= pd.read_csv('C:\\Users\\HP PAVILION GAMING\\OneDrive\\Рабочий стол\\new19_9\\birlashgan.csv')


plt.plot(hamma.year_zodiac, hamma.med_frequency, color = "yellow")
plt.plot(hamma.year_zodiac, hamma.ph_frequency, color = "tab:brown")
plt.plot(hamma.year_zodiac, hamma.ch_frequency, color = "tab:purple")

font1 = {'family':'serif','color':'blue','size':20}
plt.title('Nobel prize winners\' zodiacs of born year and categories of medicine, physics, chemistry', fontdict = font1, loc = 'center')
plt.legend(['medicine', 'physics',  'chemistry'], bbox_to_anchor=(0.9,1), loc="upper left")
#plt.legend(bbox_to_anchor=(1.05,1))
plt.xlabel('zodiacs of year')
plt.xticks(rotation=90)
plt.ylabel('frequency')

ax = plt.subplot()
ax.grid(True)
plt.show()
# Out:
# <ipython-input-81-304601deab85>:21: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot()

# %% [markdown]
# all categories and born year zodiacs of winners

# %%
from typing import Sized
import pandas as pd
import datetime 
import numpy as nm
from matplotlib import pyplot as plt

hamma= pd.read_csv('C:\\Users\\HP PAVILION GAMING\\OneDrive\\Рабочий стол\\new19_9\\birlashgan.csv')
print(hamma)

plt.plot(hamma.year_zodiac, hamma.eco_frequency, color='blue')
plt.plot(hamma.year_zodiac, hamma.lit_frequency, color='red')
plt.plot(hamma.year_zodiac, hamma.pe_frequency, color = 'green')
plt.plot(hamma.year_zodiac, hamma.med_frequency, color = "yellow")
plt.plot(hamma.year_zodiac, hamma.ph_frequency, color = "tab:brown")
plt.plot(hamma.year_zodiac, hamma.ch_frequency, color = "tab:purple")


font1 = {'family':'serif','color':'blue','size':20}
plt.title('Nobel prize winners\' zodiacs of born year and categories', fontdict = font1, loc = 'center')
plt.legend(['economy', 'literature', 'medicine', 'peace', 'physics', 'chemistry'], bbox_to_anchor=(1,1), loc="upper left")

plt.xlabel('zodiacs of year')
plt.xticks(rotation=90)
plt.ylabel('frequency')

ax = plt.subplot()
ax.grid(True)
plt.show()
# Out:
#    year_zodiac  eco_frequency  lit_frequency  med_frequency  pe_frequency  \
# 0          dog       0.083333       0.060345       0.080357      0.056604
# 1       dragon       0.095238       0.129310       0.075893      0.103774
# 2         goat       0.083333       0.094828       0.062500      0.084906
# 3        horse       0.107143       0.094828       0.075893      0.066038
# 4       monkey       0.083333       0.025862       0.075893      0.056604
# 5           ox       0.071429       0.077586       0.071429      0.150943
# 6          pig       0.083333       0.112069       0.084821      0.113208
# 7       rabbit       0.119048       0.077586       0.107143      0.056604
# 8          rat       0.083333       0.086207       0.107143      0.094340
# 9      rooster       0.095238       0.051724       0.075893      0.056604
# 10       snake       0.059524       0.103448       0.111607      0.075472
# 11       tiger       0.035714       0.086207       0.071429      0.084906
#
# ...
