# %% [markdown]
# zodiac of winners in economy, literature and peace

# %%
from typing import Sized
import pandas as pd

import numpy as nm
from matplotlib import pyplot as plt

hamma= pd.read_csv('C:\\Users\\HP PAVILION GAMING\\OneDrive\\Рабочий стол\\new19_9\\birlashgan.csv')


plt.plot(hamma.year_zodiac, hamma.eco_frequency, color='blue')
plt.plot(hamma.year_zodiac, hamma.lit_frequency, color='red')
plt.plot(hamma.year_zodiac, hamma.pe_frequency, color = 'green')

font1 = {'family':'serif','color':'blue','size':20}
plt.title('Nobel prize winners\' zodiacs of born year and categories of economy, literature, peace', fontdict = font1, loc = 'center')
plt.legend(['economy', 'literature', 'peace'], bbox_to_anchor=(0.9,1), loc="upper left")
#plt.legend(bbox_to_anchor=(1.05,1))
plt.xlabel('zodiacs of year')
plt.xticks(rotation=90)
plt.ylabel('frequency')

ax = plt.subplot()
ax.grid(True)
plt.show()
# Out:
# <ipython-input-2-52035f3f941e>:22: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot()

# %% [markdown]
# zodiac of winners in medicine, chemistry and physics

# %%
from typing import Sized
import pandas as pd
import numpy as nm
from matplotlib import pyplot as plt

hamma= pd.read_csv('C:\\Users\\HP PAVILION GAMING\\OneDrive\\Рабочий стол\\new19_9\\birlashgan.csv')


plt.plot(hamma.year_zodiac, hamma.med_frequency, color = "yellow")
plt.plot(hamma.year_zodiac, hamma.ph_frequency, color = "tab:brown")
plt.plot(hamma.year_zodiac, hamma.ch_frequency, color = "tab:purple")

font1 = {'family':'serif','color':'blue','size':20}
plt.title('Nobel prize winners\' zodiacs of born year and categories of medicine, physics, chemistry', fontdict = font1, loc = 'center')
plt.legend(['medicine', 'physics',  'chemistry'], bbox_to_anchor=(0.9,1), loc="upper left")
#plt.legend(bbox_to_anchor=(1.05,1))
plt.xlabel('zodiacs of year')
plt.xticks(rotation=90)
plt.ylabel('frequency')

ax = plt.subplot()
ax.grid(True)
plt.show()
# Out:
# <ipython-input-3-304601deab85>:21: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot()

# %% [markdown]
# all categories and born year zodiacs of winners

# %%
from typing import Sized
import pandas as pd
import datetime 
import numpy as nm
from matplotlib import pyplot as plt

hamma= pd.read_csv('C:\\Users\\HP PAVILION GAMING\\OneDrive\\Рабочий стол\\new19_9\\birlashgan.csv')
print(hamma)

plt.plot(hamma.year_zodiac, hamma.eco_frequency, color='blue')
plt.plot(hamma.year_zodiac, hamma.lit_frequency, color='red')
plt.plot(hamma.year_zodiac, hamma.pe_frequency, color = 'green')
plt.plot(hamma.year_zodiac, hamma.med_frequency, color = "yellow")
plt.plot(hamma.year_zodiac, hamma.ph_frequency, color = "tab:brown")
plt.plot(hamma.year_zodiac, hamma.ch_frequency, color = "tab:purple")


font1 = {'family':'serif','color':'blue','size':20}
plt.title('Nobel prize winners\' zodiacs of born year and categories', fontdict = font1, loc = 'center')
plt.legend(['economy', 'literature', 'medicine', 'peace', 'physics', 'chemistry'], bbox_to_anchor=(1,1), loc="upper left")

plt.xlabel('zodiacs of year')
plt.xticks(rotation=90)
plt.ylabel('frequency')

ax = plt.subplot()
ax.grid(True)
plt.show()
# Out:
# <ipython-input-4-791f73094614>:26: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot()
#    year_zodiac  eco_frequency  lit_frequency  med_frequency  pe_frequency  \
# 0          dog       0.083333       0.060345       0.080357      0.056604
# 1       dragon       0.095238       0.129310       0.075893      0.103774
# 2         goat       0.083333       0.094828       0.062500      0.084906
# 3        horse       0.107143       0.094828       0.075893      0.066038
# 4       monkey       0.083333       0.025862       0.075893      0.056604
# 5           ox       0.071429       0.077586       0.071429      0.150943
# 6          pig       0.083333       0.112069       0.084821      0.113208
# ...

# %%
my_plot = hamma.set_index('year_zodiac').plot(kind='bar', stacked=True,title="Total frequency of winners by year zodiacs",figsize=(9, 7))
my_plot.set_xlabel("Born year zodiacs")
my_plot.set_ylabel("Frequency")
my_plot.legend(["Economy","Literature","Medicine","Peace","Physics","Chemistry"], bbox_to_anchor=(1,1), loc="upper left",ncol=1)

# %%
#hamma['all_categories_sum'] = hamma.groupby(['eco_frequency', 'lit_frequency', 'pe_frequency', 'med_frequency', 'ph_frequency', 'ch_frequency']).sum()
hamma['all_categories_sum'] = hamma['eco_frequency'] + hamma['lit_frequency'] + hamma['pe_frequency']+hamma['med_frequency']+hamma['ph_frequency']+hamma['ch_frequency']
hamma.to_csv('hamma2.csv', index=False)

# %%
hamma2= pd.read_csv('C:\\Users\\HP PAVILION GAMING\\OneDrive\\Рабочий стол\\new19_9\\hamma2.csv')
hamma2
# Out:
#    year_zodiac  eco_frequency  lit_frequency  med_frequency  pe_frequency  \
# 0          dog       0.083333       0.060345       0.080357      0.056604
# 1       dragon       0.095238       0.129310       0.075893      0.103774
# 2         goat       0.083333       0.094828       0.062500      0.084906
# 3        horse       0.107143       0.094828       0.075893      0.066038
# 4       monkey       0.083333       0.025862       0.075893      0.056604
# 5           ox       0.071429       0.077586       0.071429      0.150943
# 6          pig       0.083333       0.112069       0.084821      0.113208
# 7       rabbit       0.119048       0.077586       0.107143      0.056604
# 8          rat       0.083333       0.086207       0.107143      0.094340
# 9      rooster       0.095238       0.051724       0.075893      0.056604
# 10       snake       0.059524       0.103448       0.111607      0.075472
# 11       tiger       0.035714       0.086207       0.071429      0.084906
#
# ...

# %%
hamma2 = hamma.sort_values('all_categories_sum', ascending=False)
hamma2
# Out:
#    year_zodiac  eco_frequency  lit_frequency  med_frequency  pe_frequency  \
# 8          rat       0.083333       0.086207       0.107143      0.094340
# 10       snake       0.059524       0.103448       0.111607      0.075472
# 1       dragon       0.095238       0.129310       0.075893      0.103774
# 7       rabbit       0.119048       0.077586       0.107143      0.056604
# 3        horse       0.107143       0.094828       0.075893      0.066038
# 5           ox       0.071429       0.077586       0.071429      0.150943
# 6          pig       0.083333       0.112069       0.084821      0.113208
# 2         goat       0.083333       0.094828       0.062500      0.084906
# 11       tiger       0.035714       0.086207       0.071429      0.084906
# 9      rooster       0.095238       0.051724       0.075893      0.056604
# 0          dog       0.083333       0.060345       0.080357      0.056604
# 4       monkey       0.083333       0.025862       0.075893      0.056604
#
# ...

# %%
my_plot = hamma2[['year_zodiac', 'all_categories_sum']].set_index('year_zodiac').plot(kind='bar',figsize=(9, 7), color='red')
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
#my_plot = hamma3.sort(columns='ext price', ascending=False).plot(kind='bar',legend=None,title="Total Sales by Customer")
my_plot.set_xlabel("Zodiacs", fontdict = font2)
my_plot.set_ylabel("Frequency occurence", fontdict = font2)
plt.title('Total frequency of winners by year zodiacs', fontdict = font1, loc = 'center')
# Out:
# Text(0.5, 1.0, 'Total frequency of winners by year zodiacs')

# %%
ggzm=pd.read_csv('C:\\Users\\HP PAVILION GAMING\\OneDrive\\Рабочий стол\\new19_9\\my_data111.csv')
ggzm
# Out:
#       ID gender  win year   category  day born  month  year born zod_year  \
# 0    198   male      1938  chemistry         3     12       1900      rat
# 1    211   male      1950  chemistry        10      7       1902    tiger
# 2    208   male      1948  chemistry        10      8       1902    tiger
# 3    269   male      1987  chemistry         3     10       1904   dragon
# 4    239   male      1970  chemistry         6      9       1906    horse
# ..   ...    ...       ...        ...       ...    ...        ...      ...
# 929  100   male      1974    physics        27      9       1918    horse
# 930   46   male      1938    physics        29      9       1901       ox
# 931  116   male      1980    physics        29      9       1931     goat
# 932  944   male      2017    physics        29      9       1932   monkey
# 933  108   male      1977    physics        30      9       1905    snake
#
#        zod_month          zod all
# 0    sagittarius  rat sagittarius
# ...

# %%
#counting of procentage of all years zodiacs by all categories
ggzm1=ggzm['zod_year'].value_counts(normalize=True)
ggzm1
# Out:
# snake      0.096360
# rat        0.095289
# rabbit     0.092077
# horse      0.088865
# dragon     0.085653
# ox         0.083512
# pig        0.082441
# goat       0.080300
# tiger      0.076017
# dog        0.073876
# rooster    0.072805
# monkey     0.072805
# Name: zod_year, dtype: float64

# %%
my_plot = ggzm1.plot(kind='bar', figsize=(9, 7), color = 'red')
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
#my_plot = hamma3.sort(columns='ext price', ascending=False).plot(kind='bar',legend=None,title="Total Sales by Customer")
my_plot.set_xlabel("Zodiacs of year", fontdict = font2)
my_plot.set_ylabel("Percentage", fontdict = font2)
plt.title('Total procentage of winners by year zodiacs', fontdict = font1, loc = 'center')
plt.tight_layout()
