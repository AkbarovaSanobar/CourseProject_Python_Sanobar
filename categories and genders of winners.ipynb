# %% [markdown]
# pie chart and donut chart (percentage of categories; percentage of male, female and organizations of Nobel prise winners)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go

chemistry=org.loc[org['category'] == 'chemistry'].count()[0]
physics=org.loc[org['category'] == 'physics'].count()[0]
medicine=org.loc[org['category'] == 'medicine'].count()[0]
economics=org.loc[org['category'] == 'economics'].count()[0]
literature=org.loc[org['category'] == 'literature'].count()[0]
peace=org.loc[org['category'] == 'peace'].count()[0]
colors1 = ['red', 'lightgreen', 'yellow', 'blue', 'lightpink', 'cyan']
labels = ['chemistry', 'physics', 'medicine', 'economics', 'literature', 'peace']
fig = plt.figure(figsize=(10,10)) 
plt.rcParams.update({'font.size': 20, 'font.family': 'monospace'})
plt.pie([chemistry, physics, medicine, economics, literature, peace], labels=labels, colors=colors1, autopct='%.2f %%', wedgeprops={'edgecolor': 'black'})
plt.title('Individual winners in the fields', color='blue')
plt.show()

# %%
s=org.gender
counts=s.value_counts()
percent100=s.value_counts(normalize=True).mul(100).round(1).astype(str)# + '%'
ff=pd.DataFrame({'counts': counts, 'percent100': percent100})
ff
# Out:
#         counts percent100
# male       881       91.1
# female      58        6.0
# org         28        2.9

# %%
# donut chart
labels = ['male', 'female', 'organizations (all in the field of peace)']
values = [91.1, 6.0, 2.9]
fig = go.Figure(data=[go.Pie(labels=labels, values=values, hole=.5)])
fig.update(layout_title_text='Procentage of male, female and organizations by categories')
      
fig.show()
# Out:
# <div>                            <div id="bd9fe0f3-8c8b-48c5-9c76-a4867dd37394" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd9fe0f3-8c8b-48c5-9c76-a4867dd37394")) {                    Plotly.newPlot(                        "bd9fe0f3-8c8b-48c5-9c76-a4867dd37394",                        [{"hole":0.5,"labels":["male","female","organizations (all in the field of peace)"],"type":"pie","values":[91.1,6.0,2.9]}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"soli
# ...
