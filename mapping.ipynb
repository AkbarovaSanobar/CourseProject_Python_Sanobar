# %% [markdown]
# number of winners by their born country

# %%
import os
import conda
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
#conda_file_dir = conda.__file__
#conda_dir = conda_file_dir.split('lib')[0]
#proj_lib = os.path.join(os.path.join(conda_dir, 'share'), 'proj')
#os.environ["PROJ_LIB"] = proj_lib
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

m = Basemap(projection = 'mill', llcrnrlat=-60, urcrnrlat=90, llcrnrlon=-180, urcrnrlon = 180, resolution='c')
m.drawcoastlines()
m.drawcountries()
#m.drawstates()
#m.drawrivers()
m.fillcontinents(color='#04BAE3', lake_color='#FFFFFF')
m.drawmapboundary(fill_color='#FFFFFF')
m.bluemarble()


#US
lat, lon = 45, -102
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=27.5, alpha=.5)

#GB
lat, lon = 51.3, -0.08
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=10.1, alpha=.5)

#DE
lat, lon = 52.5, 13.41
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=8.8, alpha=.5)

#FR
lat, lon = 48.83, 2.3
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=5.6, alpha=.5)

#RU
lat, lon = 55.75, 37.58
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=3.1, alpha=.5)

#PL
lat, lon = 52.21, 21
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=3, alpha=.5)

#SE
lat, lon = 59.33, 18.05
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=3, alpha=.5)

#JP
lat, lon = 36, 138
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=2.8, alpha=.5)

#IT
lat, lon = 41.54, 12.29
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=2, alpha=.5)

#AT
lat, lon = 48.12, 16.22
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=1.9, alpha=.5)

#NL
lat, lon = 52.23, 04.54
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=1.9, alpha=.5)

#CA
lat, lon = 45.27, -75.42
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=1.8, alpha=.5)

#CH
lat, lon = 45.57, 07.28
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=1.7, alpha=.5)

#CN
lat, lon = 39.55, 116.20
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=1.3, alpha=.5)

#NO
lat, lon = 59.55, 10.45
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=1.3, alpha=.5)

#DK
lat, lon = 55.41, 12.34
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=1.2, alpha=.5)

#AU
lat, lon = -35.25, 149.13
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=1.1, alpha=.5)

#BE
lat, lon = 50.51, 4.21
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=0.9, alpha=.5)

#HU
lat, lon = 47.29, 19.05
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=0.9, alpha=.5)

#ZA
lat, lon = -25.44, 28.12
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=0.9, alpha=.5)

#IN
lat, lon = 28.37, 77.13
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=0.8, alpha=.5)


#ES
lat, lon = 40.25, -3.45
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=0.7, alpha=.5)

#CZ
lat, lon = 50.05, 14.22
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=0.6, alpha=.5)

#EG
lat, lon = 30.01, 31.14
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=0.6, alpha=.5)

#IL
lat, lon = 31.47, 35.12
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=0.6, alpha=.5)

#IE
lat, lon = 53.21, -6.15
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=0.5, alpha=.5)

#RO
lat, lon = 44.27, 26.10
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=0.5, alpha=.5)

#UA
lat, lon = 50.30, 30.28
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=0.5, alpha=.5)

#AR
lat, lon = -36.3, -60
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=0.4, alpha=.5)

#BY
lat, lon = 53.52, 27.30
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=0.4, alpha=.5)

#PK
lat, lon = 33.40, 73.10
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=0., alpha=.5)

#DZ
lat, lon = 36.42, 3.08
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=0.3, alpha=.5)

#FI
lat, lon = 60.15, 25.03
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=0.3, alpha=.5)

#LT
lat, lon = 54.38, 25.19
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=0.3, alpha=.5)

#MX
lat, lon = 19.20, -99.10
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=0.3, alpha=.5)

#NZ
lat, lon = -41.19, 174.46
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=0.3, alpha=.5)

#PT
lat, lon = 38.42, -9.10
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=0.3, alpha=.5)

#TR
lat, lon = 39.57, 32.54
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=0.3, alpha=.5)

#BA
lat, lon = 43.52, 18.26
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=0.2, alpha=.5)

#CL
lat, lon = -33.24, -70.40
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=0.2, alpha=.5)

#CO
lat, lon = 4.34, -74
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=0.2, alpha=.5)

#GT
lat, lon = 14.40, -90.22
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=0.2, alpha=.5)

#IR
lat, lon = 35.44, -51.30
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=0.2, alpha=.5)

#KR
lat, lon = 37.31, 126.58
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=0.2, alpha=.5)

#LC
lat, lon = 14.02, -60.58
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=0.2, alpha=.5)

#LR
lat, lon = 6.18, -10.47
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=0.2, alpha=.5)

#LU
lat, lon = 49.37, 6.09
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=0.2, alpha=.5)

#MA
lat, lon = 32, -5
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=0.2, alpha=.5)

#TL
lat, lon = -8.29, 125.34
x,y = m(lon, lat)
m.plot(x,y, 'ro', markersize=0.2, alpha=.5)

plt.title('Map of winners burn country')
plt.show()
