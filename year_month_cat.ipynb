# %% [markdown]
# Month and year zodiacs

# %%
from typing import Sized
import pandas as pd
import numpy as nm
from matplotlib import pyplot as plt
from matplotlib.patches import Ellipse, Polygon

# %%
ggzm=pd.read_csv('C:\\Users\\HP PAVILION GAMING\\OneDrive\\Рабочий стол\\new19_9\\egzel2.csv')
ggzm
# Out:
#       ID gender  win_year   category  day_born  month  year_born zod_year  \
# 0    198   male      1938  chemistry         3     12       1900      rat
# 1    211   male      1950  chemistry        10      7       1902    tiger
# 2    208   male      1948  chemistry        10      8       1902    tiger
# 3    269   male      1987  chemistry         3     10       1904   dragon
# 4    239   male      1970  chemistry         6      9       1906    horse
# ..   ...    ...       ...        ...       ...    ...        ...      ...
# 929  100   male      1974    physics        27      9       1918    horse
# 930   46   male      1938    physics        29      9       1901       ox
# 931  116   male      1980    physics        29      9       1931     goat
# 932  944   male      2017    physics        29      9       1932   monkey
# 933  108   male      1977    physics        30      9       1905    snake
#
#        zod_month          zod_all  number  age_winners
# ...

# %%
ggzm1=ggzm['zod_all'].value_counts()
ggzm1
# Out:
# pig gemini          15
# goat libra          13
# ox virgo            13
# dog virgo           13
# horse gemini        12
#                     ..
# monkey aquarious     2
# tiger capricorn      2
# tiger gemini         2
# dragon pisces        1
# rooster pisces       1
# Name: zod_all, Length: 144, dtype: int64

# %%
my_plot = ggzm1.plot(kind='bar', figsize=(19, 7))
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
my_plot.set_xlabel("all zodiacs", fontdict = font2)
my_plot.set_ylabel("Number of winners", fontdict = font2)
plt.title('Number of all zodiacs of winners in the all categories', fontdict = font1, loc = 'center')
plt.tight_layout()

# %%
zz1=ggzm1[:10]
zz2=ggzm1[134:]
zz3=pd.concat([zz1, zz2])
zz3

my_plot = zz3.plot(kind='bar', figsize=(9, 7))
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
my_plot.set_xlabel("zodiacs", fontdict = font2)
my_plot.set_ylabel("Number of winners", fontdict = font2)
plt.title('The best 10 and the worst 10 zodiacs of born year in the all categories', fontdict = font1, loc = 'center')
plt.tight_layout()

# %%
ggzm1.to_csv('allzodpercent.csv')

# %%
allz=pd.read_csv('allzodpercent.csv')
allz
# Out:
#            Unnamed: 0  zod_all
# 0          pig gemini       15
# 1          goat libra       13
# 2            ox virgo       13
# 3           dog virgo       13
# 4        horse gemini       12
# ..                ...      ...
# 139  monkey aquarious        2
# 140   tiger capricorn        2
# 141      tiger gemini        2
# 142     dragon pisces        1
# 143    rooster pisces        1
#
# [144 rows x 2 columns]

# %%
allz.rename(columns= {'Unnamed: 0': 'zod_all', 'zod_all':'percentage'}, inplace=True)
allz
# Out:
#               zod_all  percentage
# 0          pig gemini          15
# 1          goat libra          13
# 2            ox virgo          13
# 3           dog virgo          13
# 4        horse gemini          12
# ..                ...         ...
# 139  monkey aquarious           2
# 140   tiger capricorn           2
# 141      tiger gemini           2
# 142     dragon pisces           1
# 143    rooster pisces           1
#
# [144 rows x 2 columns]

# %%
ggzm2 = allz.sort_values('percentage', ascending=False)
ggzm2
# Out:
#               zod_all  percentage
# 0          pig gemini          15
# 2            ox virgo          13
# 3           dog virgo          13
# 1          goat libra          13
# 4        horse gemini          12
# ..                ...         ...
# 139  monkey aquarious           2
# 140   tiger capricorn           2
# 141      tiger gemini           2
# 142     dragon pisces           1
# 143    rooster pisces           1
#
# [144 rows x 2 columns]

# %%
ggzm3 = allz.sort_values('zod_all', ascending=True)
ggzm3
# Out:
#                zod_all  percentage
# 110      dog aquarious           4
# 79           dog aries           6
# 102         dog cancer           5
# 132      dog capricorn           3
# 36          dog gemini           8
# ..                 ...         ...
# 31        tiger pisces           8
# 35   tiger sagittarius           8
# 40       tiger scorpio           8
# 19        tiger taurus           9
# 47         tiger virgo           8
#
# [144 rows x 2 columns]

# %%
ggzm3.to_csv('allzodmonth_year.csv', index=False)

# %%
zgg=ggzm[['category','zod_year','zod_month']]
zgg
zgg.to_csv('gr_zod.csv', index=False)

# %%
azg=pd.read_csv('gr_zod.csv')
azg
# Out:
#       category zod_year    zod_month  number
# 0    chemistry      rat  sagittarius       1
# 1    chemistry    tiger       cancer       1
# 2    chemistry    tiger          leo       1
# 3    chemistry   dragon        libra       1
# 4    chemistry    horse        virgo       1
# ..         ...      ...          ...     ...
# 929    physics    horse        libra       1
# 930    physics       ox        libra       1
# 931    physics     goat        libra       1
# 932    physics   monkey        libra       1
# 933    physics    snake        libra       1
#
# [934 rows x 4 columns]

# %%
zodiac_group=azg.groupby(['zod_year','zod_month']).sum()
zodiac_group.head()
# Out:
#                     number
# zod_year zod_month
# dog      aquarious       4
#          aries           6
#          cancer          5
#          capricorn       3
#          gemini          8

# %%
zodiac_group.to_csv('zodiac_groupped.csv')

# %%
ggg=zodiac_group.unstack()
ggg
# Out:
#              number                                                 \
# zod_month aquarious aries cancer capricorn gemini leo libra pisces
# zod_year
# dog               4     6      5         3      8   4     5      5
# dragon            7    11      7         8      9   6     7      1
# goat              6     7     10         4      4   4    13      9
# horse             4     6      6         6     12   6    10      8
# monkey            2     8      3         3      9   6     7      7
# ox                2     6      8         4      7   9     7      5
# pig               5     4      9         6     15   5     5      6
# rabbit            5    10      9         7      7   3    11      6
# rat               9     3      8         8      9   8     8      9
# rooster           6     2      7         4      8   6     8      1
# snake            11    10      5         5     11  10     5      6
# tiger             8     6      4         2      2   4     4      8
#
#
# ...

# %%
ggg.to_csv('unstacked_group_zodiacs.csv')

# %%
zz=pd.read_csv('777.csv')
zz
# Out:
#    zod_year  aquarious  aries  cancer  capricorn  gemini  leo  libra  pisces  \
# 0       dog          4      6       5          3       8    4      5       5
# 1    dragon          7     11       7          8       9    6      7       1
# 2      goat          6      7      10          4       4    4     13       9
# 3     horse          4      6       6          6      12    6     10       8
# 4    monkey          2      8       3          3       9    6      7       7
# 5        ox          2      6       8          4       7    9      7       5
# 6       pig          5      4       9          6      15    5      5       6
# 7    rabbit          5     10       9          7       7    3     11       6
# 8       rat          9      3       8          8       9    8      8       9
# 9   rooster          6      2       7          4       8    6      8       1
# 10    snake         11     10       5          5      11   10      5       6
# ...

# %%
fig, ax = plt.subplots()
x=zz['zod_year']
y1=zz['aquarious']
sc = ax.scatter(x, y1)
ax.set_ylabel('number of winners', loc='top')
ax.set_xlabel('year zodiacs', loc='left')
#cbar = fig.colorbar(sc)
#cbar.set_label("ZLabel", loc='top')
plt.title('Number of Aquarious in year zodiacs')
plt.show()

fig, ax = plt.subplots()
x=zz['zod_year']
y2=zz['aries']
sc = ax.scatter(x, y2)
ax.set_ylabel('number of winners', loc='top')
ax.set_xlabel('year zodiacs', loc='left')
#cbar = fig.colorbar(sc)
#cbar.set_label("ZLabel", loc='top')
plt.title('Number of Aries in year zodiacs')
plt.show()


fig, ax = plt.subplots()
x=zz['zod_year']
y1=zz['cancer']
sc = ax.scatter(x, y1)
ax.set_ylabel('number of winners', loc='top')
ax.set_xlabel('year zodiacs', loc='left')
#cbar = fig.colorbar(sc)
#cbar.set_label("ZLabel", loc='top')
plt.title('Number of cancer in year zodiacs')
plt.show()

fig, ax = plt.subplots()
x=zz['zod_year']
y1=zz['capricorn']
sc = ax.scatter(x, y1)
ax.set_ylabel('number of winners', loc='top')
ax.set_xlabel('year zodiacs', loc='left')
#cbar = fig.colorbar(sc)
#cbar.set_label("ZLabel", loc='top')
plt.title('Number of capricorn in year zodiacs')
plt.show()

fig, ax = plt.subplots()
x=zz['zod_year']
y1=zz['gemini']
sc = ax.scatter(x, y1)
ax.set_ylabel('number of winners', loc='top')
ax.set_xlabel('year zodiacs', loc='left')
#cbar = fig.colorbar(sc)
#cbar.set_label("ZLabel", loc='top')
plt.title('Number of gemini in year zodiacs')
plt.show()

fig, ax = plt.subplots()
x=zz['zod_year']
y1=zz['leo']
sc = ax.scatter(x, y1)
ax.set_ylabel('number of winners', loc='top')
ax.set_xlabel('year zodiacs', loc='left')
#cbar = fig.colorbar(sc)
#cbar.set_label("ZLabel", loc='top')
plt.title('Number of leo in year zodiacs')
plt.show()

fig, ax = plt.subplots()
x=zz['zod_year']
y1=zz['libra']
sc = ax.scatter(x, y1)
ax.set_ylabel('number of winners', loc='top')
ax.set_xlabel('year zodiacs', loc='left')
#cbar = fig.colorbar(sc)
#cbar.set_label("ZLabel", loc='top')
plt.title('Number of libra in year zodiacs')
plt.show()

fig, ax = plt.subplots()
x=zz['zod_year']
y1=zz['pisces']
sc = ax.scatter(x, y1)
ax.set_ylabel('number of winners', loc='top')
ax.set_xlabel('year zodiacs', loc='left')
#cbar = fig.colorbar(sc)
#cbar.set_label("ZLabel", loc='top')
plt.title('Number of pisces in year zodiacs')
plt.show()

fig, ax = plt.subplots()
x=zz['zod_year']
y1=zz['sagittarius']
sc = ax.scatter(x, y1)
ax.set_ylabel('number of winners', loc='top')
ax.set_xlabel('year zodiacs', loc='left')
#cbar = fig.colorbar(sc)
#cbar.set_label("ZLabel", loc='top')
plt.title('Number of sagittarius in year zodiacs')
plt.show()

fig, ax = plt.subplots()
x=zz['zod_year']
y1=zz['scorpio']
sc = ax.scatter(x, y1)
ax.set_ylabel('number of winners', loc='top')
ax.set_xlabel('year zodiacs', loc='left')
#cbar = fig.colorbar(sc)
#cbar.set_label("ZLabel", loc='top')
plt.title('Number of scorpio in year zodiacs')
plt.show()

fig, ax = plt.subplots()
x=zz['zod_year']
y1=zz['taurus']
sc = ax.scatter(x, y1)
ax.set_ylabel('number of winners', loc='top')
ax.set_xlabel('year zodiacs', loc='left')
#cbar = fig.colorbar(sc)
#cbar.set_label("ZLabel", loc='top')
plt.title('Number of taurus in year zodiacs')
plt.show()

fig, ax = plt.subplots()
x=zz['zod_year']
y1=zz['virgo']
sc = ax.scatter(x, y1)
ax.set_ylabel('number of winners', loc='top')
ax.set_xlabel('year zodiacs', loc='left')
#cbar = fig.colorbar(sc)
#cbar.set_label("ZLabel", loc='top')
plt.title('Number of virgo in year zodiacs')
plt.show()

# %%
che=ggzm.loc[ggzm['category'] == 'chemistry']
ch1=che['zod_all'].value_counts(normalize=True)
ch1
# Out:
# snake aquarious    0.026738
# snake aries        0.021390
# ox virgo           0.021390
# rat libra          0.021390
# monkey aries       0.021390
#                      ...
# dragon libra       0.005348
# ox gemini          0.005348
# rat aries          0.005348
# goat leo           0.005348
# goat capricorn     0.005348
# Name: zod_all, Length: 107, dtype: float64

# %%
phy=ggzm.loc[ggzm['category'] == 'physics']
ph1=phy['zod_all'].value_counts(normalize=True)
ph1
# Out:
# goat cancer          0.027650
# horse pisces         0.018433
# snake aquarious      0.018433
# rabbit libra         0.018433
# monkey scorpio       0.018433
#                        ...
# horse sagittarius    0.004608
# goat leo             0.004608
# pig taurus           0.004608
# dog taurus           0.004608
# monkey aries         0.004608
# Name: zod_all, Length: 114, dtype: float64

# %%
me=ggzm.loc[ggzm['category'] == 'medicine']
me=me['zod_all'].value_counts(normalize=True)
me
# Out:
# horse gemini        0.022321
# tiger pisces        0.022321
# pig gemini          0.022321
# rabbit scorpio      0.022321
# rabbit libra        0.017857
#                       ...
# rabbit pisces       0.004464
# rat aquarious       0.004464
# ox cancer           0.004464
# rabbit virgo        0.004464
# monkey capricorn    0.004464
# Name: zod_all, Length: 108, dtype: float64

# %%
ec=ggzm.loc[ggzm['category'] == 'economics']
ec=ec['zod_all'].value_counts(normalize=True)
ec
# Out:
# rabbit aquarious     0.035714
# dragon gemini        0.035714
# pig taurus           0.035714
# rooster leo          0.023810
# dog virgo            0.023810
#                        ...
# monkey libra         0.011905
# horse pisces         0.011905
# tiger sagittarius    0.011905
# monkey gemini        0.011905
# ox pisces            0.011905
# Name: zod_all, Length: 64, dtype: float64

# %%
lit=ggzm.loc[ggzm['category'] == 'literature']
lit=lit['zod_all'].value_counts(normalize=True)
lit
# Out:
# snake leo             0.025862
# goat libra            0.025862
# snake gemini          0.025862
# tiger aquarious       0.025862
# pig gemini            0.025862
#                         ...
# dragon leo            0.008621
# ox cancer             0.008621
# dragon sagittarius    0.008621
# goat taurus           0.008621
# dog libra             0.008621
# Name: zod_all, Length: 79, dtype: float64

# %%
pe=ggzm.loc[ggzm['category'] == 'peace']
pe=pe['zod_all'].value_counts(normalize=True)
pe
# Out:
# snake virgo         0.037736
# pig libra           0.028302
# rabbit gemini       0.028302
# ox leo              0.028302
# ox sagittarius      0.028302
#                       ...
# ox gemini           0.009434
# dog aquarious       0.009434
# goat sagittarius    0.009434
# tiger capricorn     0.009434
# goat capricorn      0.009434
# Name: zod_all, Length: 73, dtype: float64

# %%
ch_best_az=ch1[:10]
#ch_worst_az=ch1[97:]
#ch_bw=pd.concat([ch_best_az, ch_worst_az])

my_plot = ch_best_az.plot(kind='bar', figsize=(9, 7),edgecolor='blue', facecolor='lightblue', linewidth=2, hatch="-")
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
my_plot.set_xlabel("zodiacs", fontdict = font2)
my_plot.set_ylabel("Frequency occurence", fontdict = font2)
plt.title('Frequency of the best 10 (from 107) zodiacs in the category of Chemistry', fontdict = font1, loc = 'center')
plt.tight_layout()

# %%
ph_best_az=ph1[:10]
#ph_worst_az=ph1[104:]
#ph_bw=pd.concat([ph_best_az, ph_worst_az])

my_plot = ph_best_az.plot(kind='bar', figsize=(9, 7), edgecolor='black', facecolor='darksalmon', hatch='\\')
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
my_plot.set_xlabel("zodiacs", fontdict = font2)
my_plot.set_ylabel("Frequency occurence", fontdict = font2)
plt.title('Frequency of the best 10 (from 114) zodiacs in the category of Physics', fontdict = font1, loc = 'center')
plt.tight_layout()

# %%
me_best_az=me[:10]
#me_worst_az=me[98:]
#me_bw=pd.concat([me_best_az, me_worst_az])

#my_plot = me_best_az.plot(kind='bar', figsize=(9, 7), edgecolor='black', facecolor='y', hatch=['o'])
my_plot = ec_best_az.plot(kind='bar', figsize=(9, 7), facecolor='orangered',edgecolor='black',linewidth=2, hatch="\,O,/")
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
my_plot.set_xlabel("zodiacs", fontdict = font2)
my_plot.set_ylabel("Frequency occurence", fontdict = font2)
plt.title('Frequency of the best 10 (from 108) zodiacs in the category of Medicine', fontdict = font1, loc = 'center')
plt.tight_layout()

# %%
ec_best_az=ec[:10]
my_plot = ec_best_az.plot(kind='bar', figsize=(9, 7), facecolor='violet',edgecolor='black',linewidth=3, hatch="+")
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
my_plot.set_xlabel("zodiacs", fontdict = font2)
my_plot.set_ylabel("Frequency occurence", fontdict = font2)
plt.title('Frequency of the best 10 (from 64) zodiacs in the category of Economics', fontdict = font1, loc = 'center')
plt.tight_layout()

# %%
li_best_az=lit[:10]
#my_plot = li_best_az.plot(kind='bar', figsize=(9, 7), hatch=['o'], edgecolor='red', facecolor='g')
my_plot = li_best_az.plot(kind='bar', figsize=(9, 7), facecolor='g',edgecolor='black', hatch="o")
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
my_plot.set_xlabel("zodiacs", fontdict = font2)
my_plot.set_ylabel("Frequency occurence", fontdict = font2)
plt.title('Frequency of the best 10 (from 79) zodiacs in the category of Literature', fontdict = font1, loc = 'center')
plt.tight_layout()

# %%
pe_best_az=pe[:10]
my_plot = pe_best_az.plot(kind='bar', figsize=(9, 7), edgecolor='black', hatch="*")
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
my_plot.set_xlabel("zodiacs", fontdict = font2)
my_plot.set_ylabel("Frequency occurence", fontdict = font2)
plt.title('Frequency of the best 10 (from 73) zodiacs in the category of Peace', fontdict = font1, loc = 'center')
plt.tight_layout()
