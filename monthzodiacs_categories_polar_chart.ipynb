# %% [markdown]
# Relation month zodiac with categories of winners

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
ggzm=pd.read_csv('C:\\Users\\HP PAVILION GAMING\\OneDrive\\Рабочий стол\\new19_9\\my_data111.csv')
#all categories and zodiac of born month
month_zodiac_cat=ggzm[['category', 'zod_month']]
month_zodiac_cat
# Out:
#       category    zod_month
# 0    chemistry  sagittarius
# 1    chemistry       cancer
# 2    chemistry          leo
# 3    chemistry        libra
# 4    chemistry        virgo
# ..         ...          ...
# 929    physics        libra
# 930    physics        libra
# 931    physics        libra
# 932    physics        libra
# 933    physics        libra
#
# [934 rows x 2 columns]

# %%
month_zodiac_cat.to_csv('month_zodiac_cat.csv', index=False)
mzc=pd.read_csv('C:\\Users\\HP PAVILION GAMING\\OneDrive\\Рабочий стол\\new19_9\\month_zodiac_cat.csv')
mzc
# Out:
#       category    zod_month
# 0    chemistry  sagittarius
# 1    chemistry       cancer
# 2    chemistry          leo
# 3    chemistry        libra
# 4    chemistry        virgo
# ..         ...          ...
# 929    physics        libra
# 930    physics        libra
# 931    physics        libra
# 932    physics        libra
# 933    physics        libra
#
# [934 rows x 2 columns]

# %%
# month zodiak in the field of chemistry
chemistry_month = mzc[mzc.category == "chemistry"]
chemistry_month
# Out:
#       category    zod_month
# 0    chemistry  sagittarius
# 1    chemistry       cancer
# 2    chemistry          leo
# 3    chemistry        libra
# 4    chemistry        virgo
# ..         ...          ...
# 182  chemistry        virgo
# 183  chemistry        virgo
# 184  chemistry        libra
# 185  chemistry        libra
# 186  chemistry        libra
#
# [187 rows x 2 columns]

# %%
# counting of number of year zodiak in the fields 
ch=chemistry_month['zod_month'].value_counts(normalize=True)
ch
# Out:
# virgo          0.122995
# libra          0.096257
# taurus         0.096257
# aries          0.090909
# cancer         0.090909
# leo            0.085561
# pisces         0.085561
# gemini         0.080214
# sagittarius    0.069519
# aquarious      0.069519
# capricorn      0.058824
# scorpio        0.053476
# Name: zod_month, dtype: float64

# %%
# I prepared csv file with counting  percentage of all zodiacs in all categories for further visualization (see "merging columns for month_zodiacs.ipynb")
m=pd.read_csv('C:\\Users\\HP PAVILION GAMING\\OneDrive\\Рабочий стол\\new19_9\\ham_mon11.csv')
m
# Out:
#       zod_month  perc_ch  perc_ph  perc_me  perc_ec  perc_li  perc_pe  \
# 0         virgo     12.3     10.1     10.7     10.7      3.4      8.5
# 1         libra      9.6      8.3      8.9      6.0     13.8     12.3
# 2        taurus      9.6      8.3      6.2     10.7      9.5      6.6
# 3         aries      9.1      8.3      8.5      7.1      9.5      7.5
# 4        cancer      9.1     11.5      6.2      7.1     11.2      5.7
# 5        pisces      8.6      7.8      8.5      7.1      4.3      7.5
# 6           leo      8.6      7.8      4.5      9.5     10.3      7.5
# 7        gemini      8.0      9.2     13.8     13.1     11.2     10.4
# 8     aquarious      7.0      8.3      7.1      4.8      8.6      7.5
# 9   sagittarius      7.0      8.8      8.5      8.3      6.9      5.7
# 10    capricorn      5.9      3.7      8.0      6.0      3.4     13.2
# 11      scorpio      5.3      7.8      8.9      9.5      7.8      7.5
#
#     all_categories_sum
# 0                 55.7
# ...

# %%
#polar chart of frequency of month zodiacs in the category of chemistry
from matplotlib import pyplot as plt
import numpy as np

freq = m['perc_ch']
zodiacs = ['aquarious','aries','cancer', 'capricorn','gemini','leo','libra', 'pisces','sagittarius',  'scorpio', 'taurus',    
              'virgo']


fr = np.array(freq)
fig = plt.figure(figsize=(8,8))
colors=np.array(['lime', 'red', 'cyan', 'bisque', 'violet', 'yellow', 'grey', 
                 'lightcoral', 'lightsteelblue', 'pink', 'orange', 'blue'])

N = 12
theta=np.arange(0,2*np.pi,2*np.pi/N)
width = (2*np.pi)/N *0.9
bottom = True
bottom=0
rotations = np.rad2deg(theta)
ax = fig.add_axes([0.1, 0.1, 0.75, 0.75], polar=True)
bars = ax.bar(theta, freq, width=width, bottom=bottom, color=colors)
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'black','size':15}
plt.title("Frequency of month zodiacs in the category of chemistry", fontdict = font1)
for x, bar, rotation, label in zip(theta, bars, rotations, zodiacs):
    lab = ax.text(x,bottom+bar.get_height() , label, fontdict = font2,
             ha='right', va='center', rotation=rotation, rotation_mode="anchor")  
plt.show()

# %%
#polar chart of "Frequency of month zodiacs in the category of physics"


freq = m['perc_ph']
zodiacs = ['aquarious','aries','cancer', 'capricorn','gemini','leo', 'libra', 'pisces','sagittarius',  'scorpio', 'taurus',    
              'virgo']


fr = np.array(freq)
fig = plt.figure(figsize=(8,8))
colors=np.array(['lime', 'red', 'cyan', 'bisque', 'violet', 'yellow', 'grey', 
                 'lightcoral', 'lightsteelblue', 'pink', 'orange', 'blue'])

N = 12
theta=np.arange(0,2*np.pi,2*np.pi/N)
width = (2*np.pi)/N *0.9
bottom = True
bottom=0
rotations = np.rad2deg(theta)
ax = fig.add_axes([0.1, 0.1, 0.75, 0.75], polar=True)
bars = ax.bar(theta, freq, width=width, bottom=bottom, color=colors)
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'black','size':15}
plt.title("Frequency of month zodiacs in the category of physics", fontdict = font1)
for x, bar, rotation, label in zip(theta, bars, rotations, zodiacs):
    lab = ax.text(x,bottom+bar.get_height() , label, fontdict = font2,
             ha='right', va='center', rotation=rotation, rotation_mode="anchor")  
plt.show()

# %%
#polar chart of "Frequency of month zodiacs in the category of medicine"


freq = m['perc_me']
zodiacs = ['aquarious','aries','cancer', 'capricorn','gemini','leo', 'libra', 'pisces','sagittarius',  'scorpio', 'taurus',    
              'virgo']


fr = np.array(freq)
fig = plt.figure(figsize=(8,8))
colors=np.array(['lime', 'red', 'cyan', 'bisque', 'violet', 'yellow', 'grey', 
                 'lightcoral', 'lightsteelblue', 'pink', 'orange', 'blue'])

N = 12
theta=np.arange(0,2*np.pi,2*np.pi/N)
width = (2*np.pi)/N *0.9
bottom = True
bottom=0
rotations = np.rad2deg(theta)
ax = fig.add_axes([0.1, 0.1, 0.75, 0.75], polar=True)
bars = ax.bar(theta, freq, width=width, bottom=bottom, color=colors)
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'black','size':15}
plt.title("Frequency of month zodiacs in the category of medicine", fontdict = font1)
for x, bar, rotation, label in zip(theta, bars, rotations, zodiacs):
    lab = ax.text(x,bottom+bar.get_height() , label, fontdict = font2,
             ha='right', va='center', rotation=rotation, rotation_mode="anchor")  
plt.show()

# %%
#polar chart of "Frequency of month zodiacs in the category of economics"


freq = m['perc_ec']
zodiacs = ['aquarious','aries','cancer', 'capricorn','gemini','leo', 'libra', 'pisces','sagittarius',  'scorpio', 'taurus',    
              'virgo']


fr = np.array(freq)
fig = plt.figure(figsize=(8,8))
colors=np.array(['lime', 'red', 'cyan', 'bisque', 'violet', 'yellow', 'grey', 
                 'lightcoral', 'lightsteelblue', 'pink', 'orange', 'blue'])

N = 12
theta=np.arange(0,2*np.pi,2*np.pi/N)
width = (2*np.pi)/N *0.9
bottom = True
bottom=0
rotations = np.rad2deg(theta)
ax = fig.add_axes([0.1, 0.1, 0.75, 0.75], polar=True)
bars = ax.bar(theta, freq, width=width, bottom=bottom, color=colors)
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'black','size':15}
plt.title("Frequency of month zodiacs in the category of economics", fontdict = font1)
for x, bar, rotation, label in zip(theta, bars, rotations, zodiacs):
    lab = ax.text(x,bottom+bar.get_height() , label, fontdict = font2,
             ha='right', va='center', rotation=rotation, rotation_mode="anchor")  
plt.show()

# %%
#polar chart of "Frequency of month zodiacs in the category of literature"


freq = m['perc_li']
zodiacs = ['aquarious','aries','cancer', 'capricorn','gemini','leo', 'libra', 'pisces','sagittarius',  'scorpio', 'taurus',    
              'virgo']


fr = np.array(freq)
fig = plt.figure(figsize=(8,8))
colors=np.array(['lime', 'red', 'cyan', 'bisque', 'violet', 'yellow', 'grey', 
                 'lightcoral', 'lightsteelblue', 'pink', 'orange', 'blue'])

N = 12
theta=np.arange(0,2*np.pi,2*np.pi/N)
width = (2*np.pi)/N *0.9
bottom = True
bottom=0
rotations = np.rad2deg(theta)
ax = fig.add_axes([0.1, 0.1, 0.75, 0.75], polar=True)
bars = ax.bar(theta, freq, width=width, bottom=bottom, color=colors)
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'black','size':15}
plt.title("Frequency of month zodiacs in the category of literature", fontdict = font1)
for x, bar, rotation, label in zip(theta, bars, rotations, zodiacs):
    lab = ax.text(x,bottom+bar.get_height() , label, fontdict = font2,
             ha='right', va='center', rotation=rotation, rotation_mode="anchor")  
plt.show()

# %%
#polar chart of "Frequency of month zodiacs in the category of peace"


freq = m['perc_pe']
zodiacs = ['aquarious','aries','cancer', 'capricorn','gemini','leo', 'libra', 'pisces','sagittarius',  'scorpio', 'taurus',    
              'virgo']


fr = np.array(freq)
fig = plt.figure(figsize=(8,8))
colors=np.array(['lime', 'red', 'cyan', 'bisque', 'violet', 'yellow', 'grey', 
                 'lightcoral', 'lightsteelblue', 'pink', 'orange', 'blue'])

N = 12
theta=np.arange(0,2*np.pi,2*np.pi/N)
width = (2*np.pi)/N *0.9
bottom = True
bottom=0
rotations = np.rad2deg(theta)
ax = fig.add_axes([0.1, 0.1, 0.75, 0.75], polar=True)
bars = ax.bar(theta, freq, width=width, bottom=bottom, color=colors)
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'black','size':15}
plt.title("Frequency of month zodiacs in the category of peace", fontdict = font1)
for x, bar, rotation, label in zip(theta, bars, rotations, zodiacs):
    lab = ax.text(x,bottom+bar.get_height() , label, fontdict = font2,
             ha='right', va='center', rotation=rotation, rotation_mode="anchor")  
plt.show()
