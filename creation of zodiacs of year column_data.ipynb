# %%
import numpy as np
import pandas as pd
from openpyxl import load_workbook

df = pd.read_csv('C:\\Users\\HP PAVILION GAMING\\OneDrive\\Рабочий стол\\PythonUS\\my_data222.csv')
ddf=df.rename(columns= {'day born':'day_born', 'year born':'year_born'})
ddf
# Out:
#       ID gender  win year   category  day_born  month  year_born zod_year  \
# 0    198   male      1938  chemistry         3     12       1900      rat
# 1    211   male      1950  chemistry        10      7       1902    tiger
# 2    208   male      1948  chemistry        10      8       1902    tiger
# 3    269   male      1987  chemistry         3     10       1904   dragon
# 4    239   male      1970  chemistry         6      9       1906    horse
# ..   ...    ...       ...        ...       ...    ...        ...      ...
# 929  100   male      1974    physics        27      9       1918    horse
# 930   46   male      1938    physics        29      9       1901       ox
# 931  116   male      1980    physics        29      9       1931     goat
# 932  944   male      2017    physics        29      9       1932   monkey
# 933  108   male      1977    physics        30      9       1905    snake
#
#        zod_month          zod all
# 0    sagittarius  rat sagittarius
# ...

# %%
ddf[['ID', 'day_born','month','year_born']]
# Out:
#       ID  day_born  month  year_born
# 0    198         3     12       1900
# 1    211        10      7       1902
# 2    208        10      8       1902
# 3    269         3     10       1904
# 4    239         6      9       1906
# ..   ...       ...    ...        ...
# 929  100        27      9       1918
# 930   46        29      9       1901
# 931  116        29      9       1931
# 932  944        29      9       1932
# 933  108        30      9       1905
#
# [934 rows x 4 columns]

# %%
dfa=ddf['year_born']
dfa
# Out:
# 0      1900
# 1      1902
# 2      1902
# 3      1904
# 4      1906
#        ...
# 929    1918
# 930    1901
# 931    1931
# 932    1932
# 933    1905
# Name: year_born, Length: 934, dtype: int64

# %%
c=ddf.year_born
b=[]

for i in c:
        if i%12 == 4:
            b.append('rat')
        elif i%12 == 5:
            b.append('ox')
        elif i%12 == 6:
            b.append('tiger')
        elif i%12 == 7:
            b.append('rabbit')
        elif i%12 == 8:
            b.append('dragon')
        elif i%12 == 9:
            b.append('snake')
        elif i%12 == 10:
            b.append('horse')
        elif i%12 == 11:
            b.append('goat')
        elif i%12 == 1:
            b.append('monkey')
        elif i%12 == 2:
            b.append('rooster')
        elif i%12 == 3:
            b.append('dog')
        elif i%12 == 0:
            b.append('pig')
        else:
            b.append('some error')

b
# Out:
# ['rat',
#  'tiger',
#  'tiger',
#  'dragon',
#  'horse',
#  'goat',
#  'rooster',
#  'rooster',
#  'dog',
#  'ox',
#  'snake',
#  'snake',
#  'snake',
#  'horse',
#  'horse',
#  'horse',
#  'horse',
#  'goat',
#  'pig',
#  'dog',
#  'tiger',
#  'rabbit',
#  'dragon',
#  'horse',
#  'horse',
#  'monkey',
#  'rat',
#  'tiger',
#  'tiger',
#  'rabbit',
#  'rabbit',
#  'dragon',
#  'snake',
#  'snake',
#  'horse',
#  'goat',
#  'monkey',
#  'rooster',
#  'dog',
#  'dog',
#  'dog',
#  'dragon',
#  'dog',
#  'pig',
#  'goat',
#  'rat',
#  'dragon',
#  'snake',
#  'monkey',
#  'goat',
#  'rabbit',
#  'goat',
#  'snake',
#  'snake',
#  'pig',
#  'pig',
#  'goat',
#  'ox',
#  'pig',
#  'ox',
#  'snake',
#  'goat',
#  'goat',
#  'monkey',
#  'monkey',
#  'pig',
#  'ox',
#  'pig',
#  'monkey',
#  'rat',
#  'rabbit',
#  'snake',
#  'monkey',
#  'pig',
#  'rooster',
#  'rat',
#  'goat',
#  'pig',
#  'ox',
#  'ox',
#  'ox',
#  'snake',
#  'monkey',
#  'rooster',
#  'dog',
#  'rat',
#  'rat',
# ...

# %%
ddf['new']=b
ddf
# Out:
#       ID gender  win year   category  day_born  month  year_born zod_year  \
# 0    198   male      1938  chemistry         3     12       1900      rat
# 1    211   male      1950  chemistry        10      7       1902    tiger
# 2    208   male      1948  chemistry        10      8       1902    tiger
# 3    269   male      1987  chemistry         3     10       1904   dragon
# 4    239   male      1970  chemistry         6      9       1906    horse
# ..   ...    ...       ...        ...       ...    ...        ...      ...
# 929  100   male      1974    physics        27      9       1918    horse
# 930   46   male      1938    physics        29      9       1901       ox
# 931  116   male      1980    physics        29      9       1931     goat
# 932  944   male      2017    physics        29      9       1932   monkey
# 933  108   male      1977    physics        30      9       1905    snake
#
#        zod_month          zod all     new
# ...

# %%
c=ddf.year_born
b=[]
def adding():
    for i in c:
        i=1845
        while i <= 1937:
            b.append('snake')
            i = i+12
            continue
        i=1846
        while i <= 1937:
            b.append('horse')
            i = i+12
            continue
        i=1847
        while i <= 1937:
            b.append('goat')
            i = i+12
            continue
        i=1848
        while i <= 1937:
            b.append('monkey')
            i = i+12
            continue
        i=1849
        while i <= 1937:
            b.append('rooster')
            i = i+12
            continue
        i=1850
        while i <= 1937:
            b.append('dog')
            i = i+12
            continue
        i=1851
        while i <= 1937:
            b.append('pig')
            i = i+12
            continue
        i=1852
        while i <= 1937:
            b.append('rat')
            i = i+12
            continue
        i=1853
        while i <= 1937:
            b.append('ox')
            i = i+12
            continue
        i=1854
        while i <= 1937:
            b.append('tiger')
            i = i+12
            continue
        i=1855
        while i <= 1937:
            b.append('rabbit')
            i = i+12
            continue
        i=1856
        while i <= 1937:
            b.append('dragon')
            i = i+12
            continue
b
# Out:
# []

# %%
ddff['new'] = np.where(b)
ddff
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e75432a6db67> in <module>
# ----> 1 ddff['new'] = np.where(b)
#       2 ddff
#
# NameError: name 'ddff' is not defined

# %%
a = ddff['year_born']
b=[]

# %%
a = np.array(ddff['year_born'])

# %%
a = ddf['year_born']
b=[]
i=1845
while i <= 1937:
            b.append('snake')
            i = i+12
            continue
i=1846
while i <= 1937:
            b.append('horse')
            i = i+12
            continue
i=1847
while i <= 1937:
            b.append('goat')
            i = i+12
            continue
i=1848
while i <= 1937:
            b.append('monkey')
            i = i+12
            continue
i=1849
while i <= 1937:
            b.append('rooster')
            i = i+12
            continue
i=1850
while i <= 1937:
            b.append('dog')
            i = i+12
            continue
i=1851
while i <= 1937:
            b.append('pig')
            i = i+12
            continue
i=1852
while i <= 1937:
            b.append('rat')
            i = i+12
            continue
i=1853
while i <= 1937:
            b.append('ox')
            i = i+12
            continue
i=1854
while i <= 1937:
            b.append('tiger')
            i = i+12
            continue
i=1855
while i <= 1937:
            b.append('rabbit')
            i = i+12
            continue
i=1856
while i <= 1937:
            b.append('dragon')
            i = i+12
            continue
b
# Out:
# ['snake',
#  'snake',
#  'snake',
#  'snake',
#  'snake',
#  'snake',
#  'snake',
#  'snake',
#  'horse',
#  'horse',
#  'horse',
#  'horse',
#  'horse',
#  'horse',
#  'horse',
#  'horse',
#  'goat',
#  'goat',
#  'goat',
#  'goat',
#  'goat',
#  'goat',
#  'goat',
#  'goat',
#  'monkey',
#  'monkey',
#  'monkey',
#  'monkey',
#  'monkey',
#  'monkey',
#  'monkey',
#  'monkey',
#  'rooster',
#  'rooster',
#  'rooster',
#  'rooster',
#  'rooster',
#  'rooster',
#  'rooster',
#  'rooster',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'dog',
#  'pig',
#  'pig',
#  'pig',
#  'pig',
#  'pig',
#  'pig',
#  'pig',
#  'pig',
#  'rat',
#  'rat',
#  'rat',
#  'rat',
#  'rat',
#  'rat',
#  'rat',
#  'rat',
#  'ox',
#  'ox',
#  'ox',
#  'ox',
#  'ox',
#  'ox',
#  'ox',
#  'ox',
#  'tiger',
#  'tiger',
#  'tiger',
#  'tiger',
#  'tiger',
#  'tiger',
#  'tiger',
#  'rabbit',
#  'rabbit',
#  'rabbit',
#  'rabbit',
#  'rabbit',
#  'rabbit',
#  'rabbit',
#  'dragon',
# ...

# %%
ddf['newzod']=b
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-39ca2b370463> in <module>
# ----> 1 ddf['newzod']=b
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3161         else:
#    3162             # set column
# -> 3163             self._set_item(key, value)
#    3164
#    3165     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3240         """
#    3241         self._ensure_valid_index(value)
# -> 3242         value = self._sanitize_column(key, value)
#    3243         NDFrame._set_item(self, key, value)
#    3244
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3897
#    3898             # turn me into an ndarray
# ...

# %%
ddf
# Out:
#       ID gender  win year   category  day_born  month  year_born zod_year  \
# 0    198   male      1938  chemistry         3     12       1900      rat
# 1    211   male      1950  chemistry        10      7       1902    tiger
# 2    208   male      1948  chemistry        10      8       1902    tiger
# 3    269   male      1987  chemistry         3     10       1904   dragon
# 4    239   male      1970  chemistry         6      9       1906    horse
# ..   ...    ...       ...        ...       ...    ...        ...      ...
# 929  100   male      1974    physics        27      9       1918    horse
# 930   46   male      1938    physics        29      9       1901       ox
# 931  116   male      1980    physics        29      9       1931     goat
# 932  944   male      2017    physics        29      9       1932   monkey
# 933  108   male      1977    physics        30      9       1905    snake
#
#        zod_month          zod all
# 0    sagittarius  rat sagittarius
# ...

# %%
ddf['new']=b
ddf

# %%
a=[1912, 1924]
a

# %%
a
b=[]
def adding():
    for i in a:
        i=1900
        if i == 1900 or i == i+12:
                b.append('rat')
                i = i+12
                continue
        else:
                print('some error')
adding()
b

# %%
a
b=[]
def adding():
    for i in a:
        i=1900
        if i == 1900:
                b.append('rat')
                i = i+12
                continue
        else:
                print('some error')
adding()
b

# %%
a=[1900, 1901, 1912, 1948]
a
b=[]
def adding():
    for i in a:
        #i=1900
        if i == 1900:
                b.append('rat')
                i = i+12
                continue
        else:
                b.append('some error')
adding()
b

# %%
yf=pd.read_csv('yillar.csv')
yf

# %%
c=yf.years
b=[]
def adding():
    for i in c:
            if (i == 1845) or (i == i+12) or i==i+24 or i==i+36:
                b.append('snake')
                i = i+12
                continue
            elif i == 1846 or i == i+12:
                b.append('horse')
                i = i+12
                continue
            elif i == 1900 or i == i+12:
                b.append('rat')
                i = i+12
                continue
            elif i == 1848 or i == i+12:
                b.append('monkey')
                i = i+12
                continue
            else:
                b.append('some error')
adding()
b

# %%
a=[1900, 1901, 1912, 1948]
b=[]
i=1845
while i <= 1937:
    def adding():
        for i in a:
            if (i == 1845) or (i == i+12) or i==i+24 or i==i+36:
                b.append('snake')
                i = i+12
                continue
    adding()
b

# %%
a
